# %% [markdown]
# # CAO Points Analysis
#
# https://www.cao.ie/index.php?page=points&p=2021

# %%
# Regular expressions
import re
# Package for making HTTP requests
import requests as rq

# %%
#Fetch the CAO points URL
resp = rq.get('http://www2.cao.ie/points/l8.php')
# Have a look
resp
# Out:
# <Response [200]>

# %%
#Loop throught the lines of the response content.
for line in resp.iter_lines():
    if re.match('[A-Z]{2}[0-9]{3}  .*[0-9]{3} *', line.decode('utf-8')):
        print(line)
# Out:
# b'AL801  Software Design for Virtual Reality and Gaming       300      '
# b'AL802  Software Design in Artificial Intelligence for Clo   313      '
# b'AL803  Software Design for Mobile Apps and Connected Devi   350      '
# b'AL805  Computer Engineering for Network Infrastructure      321      '
# b'AL810  Quantity Surveying                                   328      '
# b'AL820  Mechanical and Polymer Engineering                   327      '
# b'AL830  General Nursing                                      451*     444'
# b'AL832  Mental Health Nursing                                440*     431'
# b'AL835  Pharmacology                                         356      '
# b'AL836  Nutrition and Health Science                         346      '
# b'AL837  Sports Science with Exercise Physiology              357      '
# b'AL838  Biotechnology                                        324      '
# b'AL839  Microbiology                                         325      '
# b'AL840  Pharmaceutical Sciences                              346      '
# b'AL841  Athletic and Rehabilitation Therapy                  477      476*'
# b'AL842  Bioveterinary Science                                338      '
# b'AL843  Physical Activity and Health Science                 306      '
# b'AL849  Culinary Entrepreneurship                            297      '
# b'AL850  Business                                             309      '
# b'AL851  Business and Law                                     302      '
# b'AL852  Accounting                                           336      '
# b'AL854  Sport Management (with international placement)      300      299'
# b'AL855  Hospitality Management (with international placeme   309      '
# b'AL857  Digital Marketing                                    304      '
# b'AL859  International Business                               308      '
# b'AL860  Social Care Practice                                 301      '
# b'AL861  Animation and Illustration (portfolio)               #575     '
# b'AL863  Graphic and Digital Design (portfolio)               #747     '
# b'AL864  Early Years Care and Education                       306      '
# b'AL870  Applied Psychology                                   484*     467*'
# b'CW018  Business (options)                                   307      '
# b'CW028  Early Childhood Education and Care                   260      '
# b'CW038  Art (portfolio)                                      #700     '
# b'CW058  Tourism and Event Management                         292      '
# b'CW068  Applied Social Studies in Professional Social Care   250      '
# b'CW078  Sustainable Farm Management and Agribusiness         270      '
# b'CW088  Visual Communications and Design                     270      '
# b'CW108  Science (options)                                    266      '
# b'CW128  Brewing and Distilling                               307      '
# b'CW138  Sport and Exercise Science                           430      423'
# b'CW148  Strength and Conditioning                            388      '
# b'CW188  Sport Rehabilitation and Athletic Therapy            451      '
# b'CW208  Computer Games Development                           272      '
# b'CW238  Software Development                                 295      '
# b'CW248  Information Technology Management                    293      '
# b'CW258  Cybercrime and IT Security                           292      '
# b'CW268  Computing in Interactive Digital Art and Design      291      '
# b'CW438  Construction (options)                               260      251'
# b'CW468  Architectural Technology                             291      283'
# b'CW478  Civil Engineering                                    465      '
# b'CW548  Mechanical Engineering                               330      328'
# b'CW558  Electronic Systems                                   280      '
# b'CW568  Aerospace Engineering                                371      359'
# b'CW578  TV and Media Production                              318      '
# b'CW708  Law - LLB                                            292      '
# b'CW728  Product Design Innovation                            246      '
# b'CW748  Early Childhood Education and Care                   290      '
# b'CW758  Professional Social Care Practice                    360      358'
# b'CW808  Media and Public Relations                           247      '
# b'CW848  Digital Marketing with Analytics                     269      '
# b'CW858  Sports Management and Coaching (options  portfolio   #700     '
# b'CW908  Business (options)                                   272      '
# b'CW938  Business with Law                                    270      '
# b'CW948  Accounting                                           319      '
# b'PC405  Social  Political and Community Studies              263      235'
# b'PC410  Arts and Humanities (fulfils Teaching Council requ   262      230'
# b'PC411  English and History (fulfils Teaching Council requ   243      224'
# b'CR105  Chemical and Biopharmaceutical Engineering           443      '
# b'CR106  Software Development                                 431      '
# b'CR108  Mechanical Engineering                               434      '
# b'CR109  Structural Engineering                               396      '
# b'CR110  Automotive Business Management and Technology        336      '
# b'CR112  Creative Digital Media at CIT Crawford College of    390      '
# b'CR116  Computer Systems                                     365      '
# b'CR121  Music at CIT Cork School of Music                    #904     #904'
# b'CR125  Popular Music at CIT Cork School of Music            #1028    '
# b'CR130  Musical Theatre at CIT Cork School of Music          #525     '
# b'CR150  Business Information Systems                         350      '
# b'CR210  Contemporary Applied Art (Ceramics  Glass  Textile   #450     '
# b'CR220  Fine Art at CIT Crawford College of Art and Design   #400     '
# b'CR225  Photography with New Media at CIT Crawford College   #435     '
# b'CR305  Physical Sciences (Common Entry)                     260      '
# b'CR310  IT Management                                        347      '
# b'CR320  Biomedical Science - Offered jointly by CIT and UC   590*     '
# b'CR325  Pharmaceutical Biotechnology                         466      '
# b'CR333  Nutrition and Health Science                         425      '
# b'CR335  Biological Sciences (Common Entry)                   473      '
# b'CR340  Analytical Chemistry with Quality Assurance          327      '
# b'CR360  Instrument Engineering                               301      '
# b'CR365  Environmental Science and Sustainable Technology     262      '
# b'CR370  Agri-Biosciences                                     368      '
# b'CR400  Accounting                                           315      '
# b'CR420  Marketing                                            290      '
# b'CR425  International Business with Language                 279      '
# b'CR430  Sport and Exercise Management                        402      '
# b'CR435  Coaching Science and Sports Pedagogy                 410      '
# b'CR440  Montessori Education                                 409      408'
# b'CR500  Engineering (Common Entry)                           475      '
# b'CR510  Sustainable Energy Engineering                       320      '
# b'CR520  Biomedical Engineering                               444      '
# b'CR560  Architectural Technology                             375      '
# b'CR565  Interior Architecture                                431      '
# b'CR570  Quantity Surveying                                   375      '
# b'CR572  Construction Management                              300      '
# b'CR580  Electrical Engineering                               342      '
# b'CR590  Electronic Engineering                               329      '
# b'CR600  Visual Communications at CIT Crawford College of A   #280     '
# b'CR660  Tourism Management                                   246      '
# b'CR700  Theatre and Drama Studies at CIT Cork School of Mu   #609     #609'
# b'CR930  Home Economics and Business                          518*     '
# b'CK101  Arts - 3 years                                       300      '
# b'CK102  Social Science                                       434      431'
# b'CK104  Arts with Music - 3 or 4 years (BMus or Chinese/Eu   #339     '
# b'CK105  Film and Screen Media - 3 years or 4 years (Intern   421      420*'
# b'CK107  Geographical and Archaeological Sciences - 3 or 4    312      '
# b'CK108  Arts International - 4 years                         440*     440'
# b'CK109  English - 3 years or 4 years (International Pathwa   367      357'
# b'CK110  World Languages                                      488      '
# b'CK111  Early Years and Childhood Studies                    409      403'
# b'CK112  Theatre and Performative Practices - 3 or 4 years    #371     '
# b'CK113  Criminology - 3 years or 4 years (International Pa   464      463'
# b'CK118  Digital Humanities and IT - 3 or 4 years (Work Exp   347      339'
# b'CK120  Applied Psychology                                   544      543*'
# b'CK121  Psychology and Computing - 3 or 4 years (Work Expe   499      488'
# b'CK122  Government and Political Science                     399      '
# b'CK123  Anthropology                                         308      '
# b'CK124  Education - Gaeilge                                  473      '
# b'CK125  Sports Studies and Physical Education                564      555*'
# b'CK201  Commerce                                             500      499*'
# b'CK202  Accounting                                           553      543*'
# b'CK203  Business Information Systems                         455      452'
# b'CK204  Finance                                              566*     566*'
# b'CK205  Commerce (International) with French                 465      '
# b'CK206  Commerce (International) with German                 466      455'
# b'CK207  Commerce (International) with Italian                423      418'
# b'CK208  Commerce (International) with Hispanic Studies       488      486'
# b'CK209  Commerce (International) with Irish                  507      '
# b'CK211  Commerce (International) with Chinese Studies        385      '
# b'CK212  Economics (through Transformational Learning) 3 or   445      444'
# b'CK213  Food Marketing and Entrepreneurship                  466      '
# b'CK214  International Development                            332      '
# b'CK301  Law (Pathways) -  3 or 4 years                       533      532*'
# b'CK302  Law and French                                       545      '
# b'CK304  Law and Irish                                        588      '
# b'CK307  Law and Business                                     589*     589*'
# b'CK401  Computer Science                                     503      495'
# b'CK402  Biological and Chemical Sciences                     555*     555'
# b'CK404  Biological  Earth and Environmental Sciences         500      495*'
# b'CK405  Genetics                                             543      '
# b'CK406  Chemical Sciences                                    532      '
# b'CK407  Mathematical Sciences                                566      '
# b'CK408  Physics and Astrophysics                             566      '
# b'CK409  Industrial Physics - Offered jointly by UCC and CI   465      '
# b'CK411  Data Science and Analytics                           531      '
# b'CK412  Agricultural Science                                 506      '
# b'CK504  Nutritional Sciences                                 555      554*'
# b'CK505  Food Science                                         463      '
# b'CK600  Engineering                                          510      509*'
# b'CK606  Architecture - Offered jointly by UCC and CIT        543      '
# b'CK701  Medicine (Undergraduate Entry - HPAT required)       #738     #737*'
# b'CK702  Dentistry                                            625*     625*'
# b'CK703  Pharmacy                                             613*     613*'
# b'CK704  Occupational Therapy                                 601*     '
# b'CK705  Speech and Language Therapy                          568      566*'
# b'CK706  Public Health Sciences                               500      '
# b'CK707  Medical and Health Sciences                          578*     '
# b'CK710  General Nursing                                      498*     497*'
# b'CK712  Children`s and General Nursing (Integrated)          565      '
# b'CK720  Mental Health Nursing                                455      452'
# b'CK730  Intellectual Disability Nursing                      431      '
# b'CK740  Midwifery                                            509*     '
# b'AC120  International Business                               294      294'
# b'AC137  Liberal Arts                                         271      270'
# b'CT125  Computing and IT                                     242      242'
# b'CT325  Business                                             253      253'
# b'CM001  Education - Primary Teaching                         508      '
# b'CM002  Education - Primary Teaching - Gaeltacht Applicant   #462     '
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-20-2266c710e2da> in <module>
#       1 #Loop throught the lines of the response content.
#       2 for line in resp.iter_lines():
# ----> 3     if re.match('[A-Z]{2}[0-9]{3}  .*[0-9]{3} *', line.decode('utf-8')):
#       4         print(line)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x96 in position 17: invalid start byte
